# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import StandardScaler

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

# %%
# Load the categorical, numerical, and target datasets
cat = pd.read_csv('categorical.csv')
cat
# Out:
#        STATE  CLUSTER HOMEOWNR GENDER  DATASRCE RFA_2R RFA_2A GEOCODE2  \
# 0         IL       36        H      F         3      L      E        C
# 1         CA       14        H      M         3      L      G        A
# 2         NC       43        U      M         3      L      E        C
# 3         CA       44        U      F         3      L      E        C
# 4         FL       16        H      F         3      L      F        A
# ...      ...      ...      ...    ...       ...    ...    ...      ...
# 95407  other       27        H      M         3      L      G        C
# 95408     TX       24        H      M         3      L      F        A
# 95409     MI       30        H      M         3      L      E        B
# 95410     CA       24        H      F         2      L      F        A
# 95411     NC       24        U      F         3      L      G        C
#
#       DOMAIN_A  DOMAIN_B  ...  DOB_YR  DOB_MM  MINRDATE_YR  MINRDATE_MM  \
# ...

# %%
num = pd.read_csv('numerical.csv')
num
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
# ...

# %%
target = pd.read_csv('target.csv')
target
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
# Apply encoding to the categoricals 
label_encoder = LabelEncoder()
cat_encoded = cat.apply(label_encoder.fit_transform)

# %%
# Split the two target variables 
X = target.drop(['TARGET_B', 'TARGET_D'], axis=1)
y_b = target['TARGET_B']
y_d = target['TARGET_D']

# %%
# Split into test and training
X_train, X_test, y_b_train, y_b_test, y_d_train, y_d_test = train_test_split(X, y_b, y_d, test_size=0.2, random_state=42)

# %%
# Upsample the minority class with smote
smote = SMOTE(random_state=42)
X_train_resampled, y_b_train_resampled = smote.fit_resample(X_train, y_b_train)
X_train_resampled, y_d_train_resampled = smote.fit_resample(X_train, y_d_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19360\1782137758.py in <module>
#       1 # Upsample the minority class with smote
#       2 smote = SMOTE(random_state=42)
# ----> 3 X_train_resampled, y_b_train_resampled = smote.fit_resample(X_train, y_b_train)
#       4 X_train_resampled, y_d_train_resampled = smote.fit_resample(X_train, y_d_train)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
# ...

# %%
# Apply train-test
rf_b = RandomForestClassifier()
rf_b.fit(X_train_resampled, y_b_train_resampled)

rf_d = RandomForestClassifier()
rf_d.fit(X_train_resampled, y_d_train_resampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19360\1270412526.py in <module>
#       1 # Apply train-test
#       2 rf_b = RandomForestClassifier()
# ----> 3 rf_b.fit(X_train_resampled, y_b_train_resampled)
#       4
#       5 rf_d = RandomForestClassifier()
#
# NameError: name 'X_train_resampled' is not defined

# %%
# Make predictions
y_b_pred = rf_b.predict(X_test)
y_d_pred = rf_d.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19360\420659321.py in <module>
#       1 # Make predictions
# ----> 2 y_b_pred = rf_b.predict(X_test)
#       3 y_d_pred = rf_d.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     806             The predicted classes.
#     807         """
# --> 808         proba = self.predict_proba(X)
#     809
#     810         if self.n_outputs_ == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     846             classes corresponds to that in the attribute :term:`classes_`.
#     847         """
# --> 848         check_is_fitted(self)
#     849         # Check data
#     850         X = self._validate_X_predict(X)
#
# ...

# %%
# Evaluate model accuracy for each of the targets
accuracy_b = accuracy_score(y_b_test, y_b_pred)
accuracy_d = accuracy_score(y_d_test, y_d_pred)
print("Accuracy for TARGET_B:", accuracy_b)
print("Accuracy for TARGET_D:", accuracy_d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19360\523789609.py in <module>
#       1 # Evaluate model accuracy for each of the targets
# ----> 2 accuracy_b = accuracy_score(y_b_test, y_b_pred)
#       3 accuracy_d = accuracy_score(y_d_test, y_d_pred)
#       4 print("Accuracy for TARGET_B:", accuracy_b)
#       5 print("Accuracy for TARGET_D:", accuracy_d)
#
# NameError: name 'y_b_pred' is not defined
